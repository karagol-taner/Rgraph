# %% [markdown]
# <a href="https://colab.research.google.com/github/karagol-taner/Rgraph/blob/main/R_graphs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Spearman test for #1

# %%
# Clearing the workspace
rm(list = ls())

# Creating the x and y vectors
x <- c(-109.52,-110.52,-112.37,-113.99,-116.49,-218.91,-212.94,-225.19,-223.04,-226.74,-98.61,
       97.74,-100.56,-102.26,-104.63,-208.62,-222.28,-206.54,-200.39,-212.45,-107.71,-106.67,-107.05,-105.5,
       -107.5,-223.05,-214.51,-216.71,-223.37,-216.01,-88.76,-91.2,-93.92,-93.46,-95.66,-171.51,-182.38,
       -195.17,-194.16,-201.55)
y <- c(-17.5,-17,-17.5,-17.2,-17.1,-18.8,-18.8,-19.1,-19.3,-19.4,-17.8,-17.8,-17.8,-17.7,-17.9,-20.9,-20.9,
       -20.9,-20.7,-20.8,-16.3,-15.6,-15.7,-15.8,-15.6,-17.9,-17.8,-17.9,-18,-17.6,-15.4,-15.3,-15.3,-15.5,
       -15.8,-17.7,-17.6,-17.6,-17.6,-17.5)

# Performing Spearman correlation test
cor_test_result <- cor.test(x, y, alternative = "two.sided", method = "spearman", exact = FALSE)

# Printing the result
print(cor_test_result)

#plot
plot(x,y)

#fancyplots
plot(x, y, pch = 19, col = "lightblue")
# Regression line
abline(lm(y ~ x), col = "red", lwd = 3)
# Out:
# 	Spearman's rank correlation rho
#
# data:  x and y
# S = 3083.8, p-value = 2.774e-07
# alternative hypothesis: true rho is not equal to 0
# sample estimates:
#       rho
# 0.7107092
# plot without title
# plot without title

# %% [markdown]
# ## **Normal Mode Analysis**

# %%
## Install package
install.packages("bio3d")
library(bio3d)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
## Download stucture
url<-"https://drive.google.com/file/d/1HZ3RZgsc15h_dGIhtoIcCKOupcroj9u-/view?usp=sharing"

download.file(url, destfile = "NMAtest2.pdb",cacheOK=TRUE)

# %%
library(bio3d)

## Fetch stucture
pdb <- read.pdb("NMAtest.pdb")

## Calculate normal modes
modes <- nma(pdb)

## Print modes
print(modes)
m7 <- mktrj.nma(modes, mode=7, file="mode_7.pdb")
plot(modes)
# Out:
#  Building Hessian...		Done in 0.012 seconds.
#  Diagonalizing Hessian...	Done in 0.017 seconds.
#
# Call:
#   nma.pdb(pdb = pdb)
#
# Class:
#   VibrationalModes (nma)
#
# Number of modes:
#   318 (6 trivial)
#
# Frequencies:
#   Mode 7: 	0
#   Mode 8: 	0.001
#   Mode 9: 	0.001
#   Mode 10: 	0.001
#   Mode 11: 	0.002
#   Mode 12: 	0.002
#
# + attr: modes, frequencies, force.constants, fluctuations,
#         U, L, xyz, mass, temp, triv.modes, natoms, call
# Plot with title “Fluctuations”
